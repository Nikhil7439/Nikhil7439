# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikhil7439/Nikhil7439/blob/Nikhil7439/NSE_project_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Data Cleaning and renaming

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv("National_Stock_Exchange_of_India_Ltd.csv")
df
# Out:
#         Symbol       Open       High        Low        LTP    Chng  % Chng  \
# 0   ADANIPORTS        750        766     713.25        715  -47.45   -6.22
# 1   ASIANPAINT   3,101.00   3,167.35   3,091.00   3,138.00   -6.25   -0.20
# 2     AXISBANK        669      674.9     660.45        661  -18.90   -2.78
# 3   BAJAJ-AUTO   3,370.00   3,383.50   3,320.00   3,335.00  -56.70   -1.67
# 4   BAJAJFINSV  17,200.00  17,237.20  16,610.00  16,684.00 -684.85   -3.94
# 5   BAJFINANCE   7,021.00   7,047.90   6,775.00   6,780.00 -345.80   -4.85
# 6   BHARTIARTL        763        763      733.1     735.85  -29.30   -3.83
# 7         BPCL     397.15      397.2        375      377.4  -22.70   -5.67
# 8    BRITANNIA   3,560.00   3,635.10   3,533.95   3,566.60   -6.80   -0.19
# 9        CIPLA        892     976.05     890.65        965   65.05    7.23
# 10   COALINDIA     157.75      159.4     155.35      155.9   -2.65   -1.67
# ...

# %%
columns_to_convert = ["Open", "High", "Low", "LTP", "Turnover (crs.)", "52w H", "52w L"]
for col in columns_to_convert:
    df[col] = df[col].astype(str).str.replace(",", "").astype(float)

# %%
df.describe()
# Out:
#                Open          High           Low           LTP        Chng  \
# count     50.000000     50.000000     50.000000     50.000000   50.000000
# mean    2985.739000   3017.261000   2914.208000   2939.569000  -70.133000
# std     5024.412163   5057.739037   4911.417131   4943.921262  163.203678
# min      125.600000    125.600000    120.500000    121.150000 -770.500000
# 25%      673.000000    678.425000    662.112500    663.187500  -66.775000
# 50%     1155.950000   1156.750000   1105.750000   1121.250000  -29.975000
# 75%     2760.262500   2789.425000   2668.537500   2690.450000   -7.812500
# max    26450.000000  26539.900000  25812.000000  25900.000000  158.400000
#
#           % Chng  Volume (lacs)  Turnover (crs.)         52w H         52w L  \
# count  50.000000      50.000000        50.000000     50.000000     50.000000
# mean   -2.930200      71.266600       569.706800   3440.588000   2208.556800
# ...

# %% [markdown]
# ##Analysis by given Data

# %%
top_gainers = df.nlargest(5, '% Chng')
top_losers = df.nsmallest(5, '% Chng')
print("Top 5 Gainers:\n", top_gainers[['Symbol', '% Chng']])
print("Top 5 Losers:\n", top_losers[['Symbol', '% Chng']])
# Out:
# Top 5 Gainers:
#         Symbol  % Chng
# 9       CIPLA    7.23
# 12    DRREDDY    3.45
# 11   DIVISLAB    2.92
# 32  NESTLEIND    0.38
# 8   BRITANNIA   -0.19
# Top 5 Losers:
#          Symbol  % Chng
# 27    JSWSTEEL   -7.48
# 42  TATAMOTORS   -6.77
# 20    HINDALCO   -6.57
# 0   ADANIPORTS   -6.22
# 23  INDUSINDBK   -6.19

# %%
plt.figure(figsize=(10, 5))
sns.histplot(df['LTP'], bins=20, kde=True, color='blue')
plt.title('Stock Price Distribution')
plt.xlabel('Last Traded Price (LTP)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.scatterplot(x=df['Volume (lacs)'], y=df['Turnover (crs.)'], hue=df['% Chng'], size=df['% Chng'], sizes=(20, 200), palette='coolwarm')
plt.title('Volume vs Turnover')
plt.xlabel('Volume (lacs)')
plt.ylabel('Turnover (crs.)')
plt.show()

# %%
df['50-day MA'] = df['LTP'].rolling(window=50, min_periods=1).mean()
plt.figure(figsize=(10, 5))
plt.plot(df['Symbol'], df['LTP'], label='LTP', marker='o')
plt.plot(df['Symbol'], df['50-day MA'], label='50-day MA', linestyle='dashed', color='red')
plt.xticks(rotation=90)
plt.title('Stock Price with 50-day Moving Average')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10, 5))
sns.boxplot(x=df['% Chng'])
plt.title('Distribution of Price Changes')
plt.xlabel('Price Change (%)')
plt.show()
